# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AgusTeresaDev/TeleconX-challenge---PARTE-2.git">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# #🛠️ Preparación de los Datos

# %% [markdown]
# #### Diccionario de datos
#
# - `customerID`: número de identificación único de cada cliente
# - `Churn`: si el cliente dejó o no la empresa
# - `gender`: género (masculino y femenino)
# - `SeniorCitizen`: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
# - `Partner`: si el cliente tiene o no una pareja
# - `Dependents`: si el cliente tiene o no dependientes
# - `tenure`: meses de contrato del cliente
# - `PhoneService`: suscripción al servicio telefónico
# - `MultipleLines`: suscripción a más de una línea telefónica
# - `InternetService`: suscripción a un proveedor de internet
# - `OnlineSecurity`: suscripción adicional de seguridad en línea
# - `OnlineBackup`: suscripción adicional de respaldo en línea
# - `DeviceProtection`: suscripción adicional de protección del dispositivo
# - `TechSupport`: suscripción adicional de soporte técnico, menor tiempo de espera
# - `StreamingTV`: suscripción de televisión por cable
# - `StreamingMovies`: suscripción de streaming de películas
# - `Contract`: tipo de contrato
# - `PaperlessBilling`: si el cliente prefiere recibir la factura en línea
# - `PaymentMethod`: forma de pago
# - `Charges.Monthly`: total de todos los servicios del cliente por mes
# - `Charges.Total`: total gastado por el cliente

# %%
import pandas as pd

# %%
datos = pd.read_csv("/content/datos_codificados_2.csv")

# %%
datos.sample(5)
# Out:
#       Churn  tenure  MultipleLines  PaperlessBilling  Charges.Monthly  \
# 3052      1       4              0                 1            79.90
# 767       1      14              0                 0            90.45
# 3519      0      67              1                 1           107.05
# 4133      0       5              0                 0            80.70
# 5465      0      64              1                 0            24.70
#
#       Cuentas_Diarias  sexo_Female  sexo_Male  SeniorCitizen_MayorIgual_65  \
# 3052         2.663333            0          1                            0
# 767          3.015000            0          1                            1
# 3519         3.568333            1          0                            1
# 4133         2.690000            1          0                            1
# 5465         0.823333            1          0                            0
#
#       SeniorCitizen_Menor_65  ...  StreamingMovies_No_Movies  \
# ...

# %%
para_borrar = ["MultipleLines", "sexo_Female", "sexo_Male", "SeniorCitizen_MayorIgual_65", "SeniorCitizen_Menor_65", "InternetService_DSL",
 "OnlineSecurity_Yes_Security", "OnlineBackup_Yes_Backup", "DeviceProtection_Yes_Protect",
 "TechSupport_Yes_Support", "StreamingTV_Yes_Streaming", "StreamingMovies_Yes_Movies", "PaymentMethod_Bank transfer (automatic)",
 "PaymentMethod_Mailed check", "gasto_total", "PaymentMethod_Credit card (automatic)"]

# %%
datos_filtrados = datos.drop(columns=para_borrar)

# %%
datos_filtrados.sample(5)
# Out:
#       Churn  tenure  PaperlessBilling  Charges.Monthly  Cuentas_Diarias  \
# 2738      0      24                 0            19.75         0.658333
# 4508      0      56                 1            59.80         1.993333
# 661       1       1                 1            69.10         2.303333
# 1385      0      72                 1           103.20         3.440000
# 2351      0      49                 1            84.50         2.816667
#
#       InternetService_Fiber optic  InternetService_No_Service  \
# 2738                            0                           1
# 4508                            0                           0
# 661                             1                           0
# 1385                            1                           0
# 2351                            1                           0
#
#       OnlineSecurity_No internet service  OnlineSecurity_No_Security  \
# 2738                                   1                           0
# ...

# %%
#datos_filtrados.to_csv("datos_filtrados.csv", index=False)

# %%
# Seleccion de variables independientes (explicativas) y dependiente (variable respuesta)
X = datos_filtrados.drop(columns="Churn")
y = datos_filtrados['Churn']

# %% [markdown]
# ## Verificación de la Proporción de Cancelación (Churn)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#CLientes que permanecen y abandoan la empresa (Churn)
sns.countplot(data=datos, x="Churn")
plt.title("Clientes que permanecen y abandonan la compañia")
plt.ylabel("Clientes")
#plt.xlabel("Permanece/Abandona")
etiquetas = ['Permanece', 'Abandona']
plt.xticks([0,1], etiquetas);

# %%
#Cantidad total por clientes
datos["Churn"].value_counts()
# Out:
# Churn
# 0    4653
# 1    1699
# Name: count, dtype: int64

# %%
#Cantidad total por clientes en porcentaje
datos["Churn"].value_counts(normalize=True)
# Out:
# Churn
# 0    0.732525
# 1    0.267475
# Name: proportion, dtype: float64

# %% [markdown]
# ## Balanceo de Datos (opcional)

# %% [markdown]
# - Se procede a balancear la clase Churn

# %%
from imblearn.over_sampling import SMOTE

# %%
sobremuestreo = SMOTE()
x_balanceada,y_balanceada = sobremuestreo.fit_resample(X,y)

# %%
y_balanceada.value_counts(normalize=True)
# Out:
# Churn
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# #🎯 Correlación y Selección de Variables

# %%
correlacion = datos_filtrados.corr()

# %%
correlacion['Churn']
# Out:
# Churn                                   1.000000
# tenure                                 -0.351333
# PaperlessBilling                        0.195949
# Charges.Monthly                         0.216299
# Cuentas_Diarias                         0.216299
# InternetService_Fiber optic             0.333644
# InternetService_No_Service             -0.244715
# OnlineSecurity_No internet service     -0.244715
# OnlineSecurity_No_Security              0.349623
# OnlineBackup_No internet service       -0.244715
# OnlineBackup_No_Backup                  0.283337
# DeviceProtection_No internet service   -0.244715
# DeviceProtection_No_Protect             0.261145
# TechSupport_No internet service        -0.244715
# TechSupport_No_Support                  0.341911
# StreamingTV_No internet service        -0.244715
# StreamingTV_No_Streaming                0.139864
# StreamingMovies_No internet service    -0.244715
# StreamingMovies_No_Movies               0.145497
# ...

# %% [markdown]
# #🤖 Modelado Predictivo

# %% [markdown]
# ## Datos de entrenamiento y prueba

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=47)

# %% [markdown]
# ## Generando un modelo de referencia - Baseline

# %%
from sklearn.dummy import DummyClassifier

# %%
dummy = DummyClassifier()
dummy.fit(X_train, y_train)
# Out:
# DummyClassifier()

# %%
#Evalua la performance del modelo dummy
dummy.score(X_test, y_test)
# Out:
# 0.732367758186398

# %% [markdown]
#  ## Uso de árboles de decisión (Modelo de árbol)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
modelo_arbol = DecisionTreeClassifier(random_state=47)
modelo_arbol.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=47)

# %%
modelo_arbol.score(X_test, y_test)
# Out:
# 0.7298488664987406

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
nombre_columnas = X_train.columns

# %%
plt.figure(figsize=(80,25))
plot_tree(modelo_arbol, filled=True, fontsize=6, class_names=["no", "si"], feature_names=nombre_columnas)
plt.show()

# %% [markdown]
# ## Parametrizando el modelo de árbol

# %%
modelo_arbol = DecisionTreeClassifier(max_depth=3, random_state=47)
modelo_arbol.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=47)

# %%
modelo_arbol.score(X_test, y_test)
# Out:
# 0.7959697732997482

# %%
plt.figure(figsize=(25,10))
plot_tree(modelo_arbol, filled=True, fontsize=10, class_names=["no", "si"], feature_names=nombre_columnas)
plt.show()

# %% [markdown]
# ## Normalizando las variables explicativas

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
normalizacion = MinMaxScaler()
X_train_normalizado = normalizacion.fit_transform(X_train)

# %% [markdown]
# ## Uso del Modelo KNN (o algoritmo KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train_normalizado, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Para probar el modelo KNN, es necesario normalizar X_test
X_test_normalizado = normalizacion.fit_transform(X_test)

# %%
#Evalua la performance del modelo
knn.score(X_test_normalizado, y_test)
# Out:
# 0.7594458438287154

# %% [markdown]
# #📋 Interpretación y Conclusiones

# %% [markdown]
# - Dado que la clase objeto presenta un desbalance, se procederá a aplicar SMOTE de la biblioteca imbalanced learn. Se procedió a balancear la clase Churn utilizando la metodología (clase) SMOTE, provista por el módulo imbalance-learn. Para el entrenamiento y prueba no se utilizó la clase balanceada.
#
# - Los datos de entrenamiento y prueba para los modelos se obtuvieron mediante el módulo de selección de la biblioteca scikit-learn train_test_split.
#
# - Se generó un modelo de referencia o dummy (baseline), con el módulo DummyClassifier de la biblioteca Scikit-learn. El score obtuvo un resultado cercano al 0.73, lo que implica que 73% de las veces el modelo realiza una clasificación correcta o una clasificación con una exactitud del 73%.
#
# - Para el modelado se utilizaron árboles de decisión, implementado mediante la biblioteca Scikit-learn, (el módulo DecisionTreeClassifier), para el cual se obtuvo un score de 0.729, es decir, el mismo que para el modelo de referencia, lo que indica un sobreajuste del modelo (overfitting).
#
# - Para mejorar el modelo, se agregaron nuevos parámetros al modelo de árbol (parametrización), indicando ahora una profundidad máxima de 3. El score, para este nuevo modelo parametrizado fue de casi un 0.80, lo que indica una mejora notable y un mejor ajuste del modelo.
#
# - Normalizando los datos: los datos usados para el entrenamiento y prueba no estaban normalizados, como por ejemplo “tenure” y “Charges.Monthly”. Esto puede implicar que algunas de las variables explicativas puedan tener más peso que otras en el resultado.
#
# - Para la normalización de las variables independientes (o explicativas), se utilizó el módulo MinMaxScaler de Scikit-learn.
#
# - Otro modelo utilizado fue el algoritmo KNN, por lo que fue necesario normalizar los datos de las variables explicativas de entrenamiento y prueba. Se utilizó el módulo KNeighborsClassifier de Scikit-learn.
#
# **Comparación de la exactitud de los modelos:**
#
# Se comparan los scores de los tres modelos desarrollados, el modelo dummy, el de árbol y el modelo KNN.
#
# - Score del modelo dummy: 0.732367758186398
# - Score del modelo de árbol: 0.7959697732997482
# - Score del modelo KNN: 0.7594458438287154
#
# Se observa que de los tres modelos, el de árbol, es el que muestra el mejor rendimiento.

# %% [markdown]
# **Observaciones y recomendaciones**
#
# Para el desarrollo y puesta apunto de los modelos, se eliminaron muchas de las variables explicativas que se consideraron innecesarias en el análisis, como ser el sexo o la edad de los clientes, por ejemplo. Tampoco se tuvieron en cuenta el gasto total ni la cantidad de líneas del cliente, que mostraban poca influencia en la variable resultado.
#
# Sin embargo, no la presencia de un servicio, pero sí su ausencia, tuvo un impacto determinante en la configuración del modelo. También el pago mensual y total fueron importantes.
#
# Esta moderada a alta correlación entre la tasa de cancelación (Churn) y los servicios (y algunas formas de pago), implica que ofrecer servicios útiles (y de calidad) al menor costo posible influyen en la fidelidad del cliente y por ende en la decisión de seguir contratando los servicios de la compañía.
#
# Lo dicho hasta ahora, para asegurar la fidelidad del cliente, la empresa debería ofrecer más servicios al menor costo posible para el cliente, premiando a su vez la permanencia y fidelidad de los mismos en la empresa.
#
# Como ya se indicó en el primer informe, una posibilidad sería renovar y mejorar los servicios para cada cliente (tal vez antes de los 10 meses), pensando en cierto nivel de personalización, con ofertas duraderas en los servicios, sin costos adicionales.
